# %%
import torch
from C_data import Gen_Dataset
from C_eval import compute_all_metrics,plot_kde_subplots
from C_model import heavy_tail_FM,Light_tail_FM,heavy_tail_input
from network import MLP,MLP_TailParam,MLP_TailParam2,MLP2,BigTimeConditionalNet,TimeToVecNet,FullConnectedScoreModel,FullConnectedScoreModel_time
from torch.autograd.functional import jacobian
from torch.distributions import Independent, Normal
from utils.extreme_transforms import TailAffineMarginalTransform_SeparateNetParam2   
from torch import nn, Tensor
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
# Out:
# cuda

# %%
approach=2
Datasetz='studentT'

# %%
if torch.cuda.is_available():
    device = 'cuda:0'
    print('Using gpu')
else:
    device = 'cpu'
    print('Using cpu.')
torch.manual_seed(42)
seed=42
# Out:
# Using gpu

# %%
Param,Data=Gen_Dataset('studentT')

# %%
dimension=Param['dimension']
num_heavy=Param['num_heavy']
name=Param['name']
hidden_dim=512
batch_size=4096
lr=0.0001
iterations=1600
STEPS=12000

# %%
model=MLP(input_dim=dimension, time_dim=1, hidden_dim=hidden_dim).to(device)
Tail_paramNet=MLP_TailParam2(time_dim=1, hidden_dim=hidden_dim//2,output_dim=4*dimension).to(device)
noise2data=TailAffineMarginalTransform_SeparateNetParam2(dimz=dimension).to(device)  #TTF

# %%
full_data_train=Data['train']
full_data_test=Data['test']
full_data_val=full_data_train

# %%
plt.scatter(full_data_train[:,0],full_data_train[:,1])
plt.xlim(-60,60)
plt.ylim(-60,60)
plt.show()

# %%
class NoiseDataset(Dataset):
    def __init__(self, length, noise_shape):
        self.length = length
        self.noise_shape = noise_shape

    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        return torch.randn(self.noise_shape)  # standard normal noise

# %%
train_dataset = TensorDataset(torch.tensor(full_data_train))
noise_shape = (full_data_train.shape[1],)  # shape of each noise sample (e.g., 100-D vector)
noise_dataset = NoiseDataset(length=len(train_dataset), noise_shape=noise_shape)
noise_loader = DataLoader(noise_dataset, batch_size=batch_size, shuffle=True)


# Create DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_7320\3808938799.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_dataset = TensorDataset(torch.tensor(full_data_train))

# %%
optim1 = torch.optim.Adam(model.parameters(), lr=lr,weight_decay=1e-3)
optim2=torch.optim.Adam(Tail_paramNet.parameters(), lr=lr,weight_decay=1e-3)#,weight_decay=1e-3)

# %%
# FM_MODEL=Light_tail_FM(model,dimension,iterations,device,STEPS)
# FM_MODEL=heavy_tail_FM(Tail_paramNet,model,noise2data,dimension,iterations,device,STEPS)
FM_MODEL=heavy_tail_input(Tail_paramNet,model,noise2data,dimension,iterations,device,STEPS)

# %%
for i in range(iterations):
    print("ITERATION-",i,"STEPS-",FM_MODEL.count)
    if FM_MODEL.steps==FM_MODEL.count:
        break
    FM_MODEL.train_epoch(optim1,optim2,train_loader,noise_loader,i)
# Out:
# ITERATION- 0 STEPS- 0
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\utils\scaler_grad.py:35: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self._scaler = torch.cuda.amp.GradScaler()
# LOSS- tensor(1640.4465, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1487.9368, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1785.7163, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1796.2179, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1438.8583, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1499.6196, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1316.5818, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1337.3015, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(11711.2939, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1389.4155, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(5376.5850, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1324.5936, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1355.6135, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1328.7546, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1708.0995, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1272.1509, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1678.8987, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1306.7185, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1366.3352, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1352.7159, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(5256.4619, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(
device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(297.4716, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(267.7117, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(1025.8079, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(341.5771, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(261.9286, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(292.1673, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(278.9100, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(279.7677, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(290.7555, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(269.6210, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(556.4882, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(294.3170, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(276.4053, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(299.3169, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(455.9890, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(246.6017, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(273.8347, device='cuda:0', grad_fn=<MeanBackward0>)
# ITERATION- 42 STEPS- 2058
# LOSS- tensor(778.5114, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(313.2361, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(329.5384, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(300.9240, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(330.3952, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(314.2608, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(270.3245, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(315.4523, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(264.8734, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(326.0500, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(277.3329, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(258.2233, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(268.8152, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(291.6588, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(717.7856, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(242.5570, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(247.6240, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(297.9339, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(272.5231, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(286.0836, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(247.9284, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(279.7295, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(284.1168, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(289.8767, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(293.8650, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(287.4556, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(285.9191, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(305.8285, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(312.2698, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(286.3506, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(289.0168, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(254.3133, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(320.0299, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(279.2727, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(314.6110, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(349.0091, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(276.6668, device='cuda:0', grad_fn=<MeanBackward0>)
# LOSS- tensor(236.3441, device='cuda:0', grad_fn=<MeanBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 if FM_MODEL.steps==FM_MODEL.count:
#       4     break
# ----> 5 FM_MODEL.train_epoch(optim1,optim2,train_loader,noise_loader,i)
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_model.py:349, in heavy_tail_input.train_epoch(self, optim1, optim2, train_loader, noise_loader, curr_iter)
#     347 loss_scaler = NativeScaler()
#     348 iI=curr_iter
# --> 349 for data,noise in zip(train_loader,noise_loader):
#     350     self.count=self.count+1
#     351     if self.count==self.steps:
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\collate.py:211, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
# --> 211     return [
#     212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\collate.py:212, in <listcomp>(.0)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\torch\utils\data\_utils\collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
generated_data=FM_MODEL.generate(full_data_test[0:10000,:].shape[0])

# %%
generated_data=generated_data
plt.scatter(generated_data[:,0],generated_data[:,1])
plt.xlim(-70,70)
plt.ylim(-70,70)
# Out:
# (-70.0, 70.0)

# %%
param_tail=FM_MODEL.Tail_paramNet(1+torch.zeros(4096).unsqueeze(1).to(device))
param_tail_pre=param_tail#self.Tail_paramNet(1+torch.zeros(num_samples,1).to(self.device)) #BX80
dummy_tail_param=param_tail_pre.reshape(param_tail_pre.shape[0],4,dimension)
const=-1
_unc_pos_tail,_unc_neg_tail,shift,_unc_scale =dummy_tail_param[:,0,:]**2+const,dummy_tail_param[:,1,:]**2+const,dummy_tail_param[:,2,:]*0,dummy_tail_param[:,3,:]*0         
param_tail=torch.cat([_unc_pos_tail,_unc_neg_tail,shift,_unc_scale],1)

x_init1 = torch.randn((batch_size, dimension), dtype=torch.float32, device=device)
x_init2=FM_MODEL.TTF(x_init1,param_tail)
# x_init1=x_init1*(x_init1>3)
# x_init2=x_init2*(x_init1>3)
plot_kde_subplots(x_init1.detach().cpu(),x_init2.detach().cpu(),'name',approach)

# %%
param_tail[0][0:4]
# Out:
# tensor([-1., -1., -1., -1.], device='cuda:0', grad_fn=<SliceBackward0>)

# %%
torch.sum(x_init1>4),torch.sum(x_init2>4)
# Out:
# (tensor(0, device='cuda:0'), tensor(158, device='cuda:0'))

# %%
plot_kde_subplots(full_data_test[0:generated_data.shape[0]],generated_data,'name',approach)

# %%
plot_kde_subplots(full_data_test[0:generated_data.shape[0]],generated_data,'name',approach)

# %%
compute_all_metrics(generated_data,full_data_test,dimension,num_heavy)
# Out:
# KURTOSIS RATIO-
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   print(compute_kurtosis_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
# -0.9434129187196882 -0.13172205151358396
# tensor(6.1621)
# SKEWNESS RATIO
# tensor(0.4399)
# loglogarea
# D- 0
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   print(compute_skewness_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:106: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   compute_loglogarea(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 compute_all_metrics(generated_data,full_data_test,dimension,num_heavy)
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:106, in compute_all_metrics(generated_data, full_data_test, dimension, num_heavy)
#     104 print(compute_skewness_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
#     105 print('loglogarea')
# --> 106 compute_loglogarea(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
#     107 print('tvar')
#     108 compute_tvar(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:68, in compute_loglogarea(dimension, num_heavy, generated_data, test_data)
#      66 for j in range(dimension):
#      67     print("D-",j)
# ---> 68     marginal_area = compute_arealoglog(test_data[:, j], generated_data[:, j])
#      69     area.append(np.round(marginal_area, 5))
#      72 area_heavy = np.mean(area[-num_heavy:])
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\marginalTailAdaptiveFlow\utils\flows.py:737, in compute_arealoglog(data_true, data_synth)
#     735 for j in range(n):
#     736     i = j + 1
# --> 737     area += np.abs( np.log(np.quantile(np.abs(data_true), 1 - i/n)) - np.log(np.quantile(np.abs(data_synth), 1 - i/n))) * np.log((i + 1)/i)
#     738 return area
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4543, in quantile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4541 if not _quantile_is_valid(q):
#    4542     raise ValueError("Quantiles must be in the range [0, 1]")
# -> 4543 return _quantile_unchecked(
#    4544     a, q, axis, out, overwrite_input, method, keepdims)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4721, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4719     else:
#    4720         arr = a.copy()
# -> 4721 result = _quantile(arr,
#    4722                    quantiles=q,
#    4723                    axis=axis,
#    4724                    method=method,
#    4725                    out=out)
#    4726 return result
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4823, in _quantile(arr, quantiles, axis, method, out)
#    4819 previous_indexes, next_indexes = _get_indexes(arr,
#    4820                                               virtual_indexes,
#    4821                                               values_count)
#    4822 # --- Sorting
# -> 4823 arr.partition(
#    4824     np.unique(np.concatenate(([0, -1],
#    4825                               previous_indexes.ravel(),
#    4826                               next_indexes.ravel(),
#    4827                               ))),
#    4828     axis=0)
#    4829 if supports_nans:
#    4830     slices_having_nans = np.isnan(arr[-1, ...])
#
# KeyboardInterrupt:

# %%
compute_all_metrics(generated_data,full_data_test,dimension,num_heavy)
# Out:
# KURTOSIS RATIO-
# -0.22130334736955204 -0.13172205151358396
# tensor(0.6801)
# SKEWNESS RATIO
# tensor(0.8104)
# loglogarea
# D- 0
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:102: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   print(compute_kurtosis_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:104: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   print(compute_skewness_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
# c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:106: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   compute_loglogarea(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 compute_all_metrics(generated_data,full_data_test,dimension,num_heavy)
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:106, in compute_all_metrics(generated_data, full_data_test, dimension, num_heavy)
#     104 print(compute_skewness_ratio(torch.tensor(generated_data),torch.tensor(full_data_test)))
#     105 print('loglogarea')
# --> 106 compute_loglogarea(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
#     107 print('tvar')
#     108 compute_tvar(dimension,num_heavy,torch.tensor(generated_data),torch.tensor(full_data_test))
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\C_eval.py:68, in compute_loglogarea(dimension, num_heavy, generated_data, test_data)
#      66 for j in range(dimension):
#      67     print("D-",j)
# ---> 68     marginal_area = compute_arealoglog(test_data[:, j], generated_data[:, j])
#      69     area.append(np.round(marginal_area, 5))
#      72 area_heavy = np.mean(area[-num_heavy:])
#
# File c:\Users\adity\OneDrive\Desktop\mscThesis\Code3\FM_HT\marginalTailAdaptiveFlow\utils\flows.py:737, in compute_arealoglog(data_true, data_synth)
#     735 for j in range(n):
#     736     i = j + 1
# --> 737     area += np.abs( np.log(np.quantile(np.abs(data_true), 1 - i/n)) - np.log(np.quantile(np.abs(data_synth), 1 - i/n))) * np.log((i + 1)/i)
#     738 return area
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4543, in quantile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4541 if not _quantile_is_valid(q):
#    4542     raise ValueError("Quantiles must be in the range [0, 1]")
# -> 4543 return _quantile_unchecked(
#    4544     a, q, axis, out, overwrite_input, method, keepdims)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4555, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4547 def _quantile_unchecked(a,
#    4548                         q,
#    4549                         axis=None,
#    (...)
#    4552                         method="linear",
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#    4558                     keepdims=keepdims,
#    4559                     axis=axis,
#    4560                     out=out,
#    4561                     overwrite_input=overwrite_input,
#    4562                     method=method)
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:3823, in _ureduce(a, func, keepdims, **kwargs)
#    3820             index_out = (0, ) * nd
#    3821             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3823 r = func(a, **kwargs)
#    3825 if out is not None:
#    3826     return out
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4721, in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4719     else:
#    4720         arr = a.copy()
# -> 4721 result = _quantile(arr,
#    4722                    quantiles=q,
#    4723                    axis=axis,
#    4724                    method=method,
#    4725                    out=out)
#    4726 return result
#
# File c:\Users\adity\anaconda3\envs\myenv_thesis\lib\site-packages\numpy\lib\function_base.py:4823, in _quantile(arr, quantiles, axis, method, out)
#    4819 previous_indexes, next_indexes = _get_indexes(arr,
#    4820                                               virtual_indexes,
#    4821                                               values_count)
#    4822 # --- Sorting
# -> 4823 arr.partition(
#    4824     np.unique(np.concatenate(([0, -1],
#    4825                               previous_indexes.ravel(),
#    4826                               next_indexes.ravel(),
#    4827                               ))),
#    4828     axis=0)
#    4829 if supports_nans:
#    4830     slices_having_nans = np.isnan(arr[-1, ...])
#
# KeyboardInterrupt:
